# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
pd.set_option('display.max_colwidth', 1000)

# %%
df = pd.DataFrame()
for i in range(1,5):
    file_name = 'data/data_' + str(i) + '.csv'
    df_data = pd.read_csv(file_name)
    df = df.append(df_data)

# %%
def remove_terms(tweet, keyword, character):
    if keyword:
        for i in keyword:       
            tweet = tweet.replace(character+i.strip("''").lower(),'')
    return tweet

# %%
# Removing some columns about user information
df = df.drop(columns=['link','username','name_x'])

# 'tweets' column to lowercase
df['tweet'] = df['tweet'].str.lower()

# Transform the data type of some columns
df['label'] = df['label'].astype(int)

# Transform object type to list
df['hashtags'] = df['hashtags'].apply(lambda x: x.strip('][').split(', ') if x != '[]' else 0)
screen_name = re.compile("screen_name': '(\w+)'")
df['reply_to'] = df['reply_to'].apply(lambda x:screen_name.findall(x))

# Remove hashtags and reply_to from tweet
df['tweet'] = df.apply(lambda row:remove_terms(row['tweet'],row['hashtags'],'#'), axis=1)
df['tweet'] = df.apply(lambda row:remove_terms(row['tweet'],row['reply_to'],'@'), axis=1)

# Add a column about 'mention'
screen_name = re.compile("@(\w+)")
df['mention'] = df['tweet'].apply(lambda x:screen_name.findall(x))

# Remove mention from tweet
df['tweet'] = df.apply(lambda row:remove_terms(row['tweet'],row['mention'],'@'), axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9150 entries, 0 to 2287
# Data columns (total 29 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              9150 non-null   object
#  1   tweet             9150 non-null   object
#  2   label             9150 non-null   int64
#  3   hashtags          9150 non-null   object
#  4   day               9150 non-null   int64
#  5   hour              9150 non-null   int64
#  6   urls              9150 non-null   object
#  7   photos            9150 non-null   object
#  8   video             9150 non-null   int64
#  9   retweet           9150 non-null   bool
#  10  nlikes            9150 non-null   int64
#  11  nreplies          9150 non-null   int64
#  12  nretweets         9150 non-null   int64
#  13  quote_url         730 non-null    object
#  14  reply_to          9150 non-null   object
#  15  bio               8400 non-null   object
#  16  url               3342 non-null   object
#  17  join_date         9150 non-null   object
#  18  join_time         9150 non-null   object
#  19  tweets            9150 non-null   int64
#  20  location          6441 non-null   object
#  21  following         9150 non-null   int64
#  22  followers         9150 non-null   int64
#  23  likes             9150 non-null   int64
#  24  media             9150 non-null   int64
#  25  private           9150 non-null   bool
#  26  verified          9150 non-null   bool
#  27  avatar            9150 non-null   object
#  28  background_image  8129 non-null   object
# dtypes: bool(3), int64(12), object(14)
# memory usage: 2.2+ MB

# %% [markdown]
# # PY section starts

# %%
df[["tweet","urls","photos","video","retweet","nlikes","nreplies","nretweets","quote_url","url"]]
# Out:
#                                                   tweet urls  \
# 0     No suicidal shit. But, why the fuck I can't fi...   []
# 1     I'm a veteran who was medically discharged for...   []
# 2                    For me, your love is suicidal ????   []
# 3     not suicidal or anything but i genuinely can't...   []
# 4     Depression really made niggas think been suici...   []
# ...                                                 ...  ...
# 9145  Years ago, in no small part as a response to m...   []
# 9146  It can't be helped... In order to stop you tha...   []
# 9147  Bruh no suicidal shit but I swear my funeral g...   []
# 9148  Suicide information for those who are struggli...   []
# 9149  @Usherwood saw a sad looking pineapple by the ...   []
#
#                                                  photos  video  retweet  \
# 0                                                    []      0    False
# 1                                                    []      0    False
# 2                                                    []      0    False
# 3                                                    []      0    False
# 4                                                    []      0    False
# ...                                                 ...    ...      ...
# 9145                                                 []      0    False
# 9146                                                 []      0    False
# 9147                                                 []      0    False
# 9148  ['https://pbs.twimg.com/media/EvGmTqgXUAgYIsB....      1    False
# 9149                                                 []      0    False
#
#       nlikes  nreplies  nretweets  \
# 0          0         0          0
# 1          5         0          0
# 2          0         0          0
# 3        136        10         38
# 4          2         0          1
# ...      ...       ...        ...
# 9145     135         1          5
# 9146       0         0          0
# 9147       1         0          0
# 9148      57         1         35
# 9149       0         1          0
#
#                                               quote_url  \
# 0                                                   NaN
# 1     https://twitter.com/Newsweek/status/1364580837...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9145                                                NaN
# 9146                                                NaN
# 9147                                                NaN
# 9148                                                NaN
# 9149                                                NaN
#
#                           url
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4     https://t.co/1TuMZ5O1eE
# ...                       ...
# 9145  https://t.co/iJrYlsmfrC
# 9146  https://t.co/77gfCAsKWb
# 9147                      NaN
# 9148  https://t.co/FtQpoISr3p
# 9149                      NaN
#
# [9150 rows x 10 columns]

# %%
df.pivot_table(index="urls",values="tweet",aggfunc="count").sort_values(by=["tweet"],ascending = False)
# Out:
#                                                     tweet
# urls
# []                                                   8618
# ['https://www.theguardian.com/environment/2021/...     10
# ['https://www.motherjones.com/politics/2021/02/...      8
# ['https://twitter.com/richardking633/status/136...      5
# ['http://www.shiningalightonsuicide.org.uk']            5
# ...                                                   ...
# ['https://music.apple.com/us/album/lift-your-he...      1
# ['https://music.apple.com/us/album/i-saw-your-m...      1
# ['https://music.apple.com/br/album/teen-idle/61...      1
# ['https://mol.im/a/9290091']                            1
# ['https://reason.com/2021/02/18/5th-circuit-gra...      1
#
# [455 rows x 1 columns]

# %%
# urls will be classified as 0 or 1
df["urls_new"] = df["urls"].apply(lambda x: "0" if x == "[]" else "1")

# %%
df[["urls_new","urls"]].head(100)
# Out:
#    urls_new                                               urls
# 0         0                                                 []
# 1         0                                                 []
# 2         0                                                 []
# 3         0                                                 []
# 4         0                                                 []
# ..      ...                                                ...
# 95        1  ['https://m.independent.ie/irish-news/irish-da...
# 96        0                                                 []
# 97        0                                                 []
# 98        0                                                 []
# 99        0                                                 []
#
# [100 rows x 2 columns]

# %%
# photos will be classified as 0 or 1
df.pivot_table(index="photos",values="tweet",aggfunc="count").sort_values(by=["tweet"],ascending = False)
# Out:
#                                                     tweet
# photos
# []                                                   8580
# ['https://pbs.twimg.com/media/Eu0CYULVIAQVVL3.j...      2
# ['https://pbs.twimg.com/media/Eu_JUW3XIAQksmC.j...      2
# ['https://pbs.twimg.com/media/Eux_4jDXEAYVtdM.j...      1
# ['https://pbs.twimg.com/media/EvDFbvwXcAI9QYR.j...      1
# ...                                                   ...
# ['https://pbs.twimg.com/media/Eu8dG8dVoAUOO0Z.j...      1
# ['https://pbs.twimg.com/media/Eu8cCWDWYAYRAeP.j...      1
# ['https://pbs.twimg.com/media/Eu8_X6GXMAIHx5L.j...      1
# ['https://pbs.twimg.com/media/Eu8_QOAVEAI7hAJ.j...      1
# ['https://pbs.twimg.com/media/EuxB-4OWQAIutT5.j...      1
#
# [569 rows x 1 columns]

# %%
# urls will be classified as 0 or 1
df["photos_new"] = df["photos"].apply(lambda x: "0" if x == "[]" else "1")

# %%
df[["photos_new","photos"]].head(100)
# Out:
#    photos_new                                             photos
# 0           0                                                 []
# 1           0                                                 []
# 2           0                                                 []
# 3           0                                                 []
# 4           0                                                 []
# ..        ...                                                ...
# 95          0                                                 []
# 96          0                                                 []
# 97          0                                                 []
# 98          0                                                 []
# 99          1  ['https://pbs.twimg.com/media/EvJ8utoVIAMEPhS....
#
# [100 rows x 2 columns]

# %%
# video is 0 or 1 - no need to process
df.video.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
# Retweet is always false - hence drop
df.retweet.unique()
# Out:
# array([False])

# %%
df.pivot_table(index="nlikes",values="tweet",aggfunc="count").sort_values(by=["tweet"],ascending = False)
# Out:
#         tweet
# nlikes
# 0        4066
# 1        1916
# 2         925
# 3         452
# 4         296
# ...       ...
# 129         1
# 123         1
# 121         1
# 120         1
# 90602       1
#
# [181 rows x 1 columns]

# %%
# need to scale
from sklearn import preprocessing

# %%
# need to scale

# %%
df.pivot_table(index="nreplies",values="tweet",aggfunc="count").sort_values(by=["tweet"],ascending = False)
# Out:
#           tweet
# nreplies
# 0          5224
# 1          2959
# 2           521
# 3           176
# 4            76
# 5            43
# 6            29
# 7            16
# 8            13
# 9            11
# 11           10
# 16            8
# 10            6
# 13            6
# 12            5
# 14            5
# 15            4
# 20            3
# 23            3
# 32            2
# 30            2
# 29            2
# 24            2
# 27            2
# 17            2
# 18            2
# 36            2
# 110           1
# 123           1
# 62            1
# 386           1
# 54            1
# 40            1
# 42            1
# 21            1
# 37            1
# 33            1
# 31            1
# 28            1
# 25            1
# 22            1
# 19            1
# 674           1

# %%
# Need to scale

# %%
df.pivot_table(index="nretweets",values="tweet",aggfunc="count").sort_values(by=["tweet"],ascending = False)
# Out:
#            tweet
# nretweets
# 0           7768
# 1            633
# 2            202
# 3            124
# 4             75
# ...          ...
# 72             1
# 75             1
# 78             1
# 81             1
# 19972          1
#
# [80 rows x 1 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = preprocessing.MinMaxScaler()
columns_to_scale = ["nlikes","nreplies","nretweets"]
new_df = MinMaxScaler().fit_transform(df[columns_to_scale])
new_df= pd.DataFrame(new_df, columns=columns_to_scale)
for c in columns_to_scale:
    df[c] = new_df[c]

# %%
df[["nlikes","nreplies","nretweets"]].head(100)
# Out:
#       nlikes  nreplies  nretweets
# 0   0.000000  0.000000   0.000000
# 1   0.000055  0.000000   0.000000
# 2   0.000000  0.000000   0.000000
# 3   0.001501  0.014837   0.001903
# 4   0.000022  0.000000   0.000050
# ..       ...       ...        ...
# 95  0.000188  0.005935   0.000250
# 96  0.000022  0.000000   0.000000
# 97  0.000011  0.000000   0.000000
# 98  0.000828  0.031157   0.000100
# 99  0.000000  0.001484   0.000000
#
# [100 rows x 3 columns]

# %%
# 0 or blank will be 0; otherwise 1

# %%
df.pivot_table(index="quote_url",values="tweet",aggfunc="count").sort_values(by=["tweet"],ascending = False)
# Out:
#                                                     tweet
# quote_url
# https://twitter.com/kmintuition/status/13635311...    100
# https://twitter.com/Mature_Gambino/status/13631...     35
# 0                                                       8
# https://twitter.com/ThaboNdawonde/status/136457...      5
# https://twitter.com/soursulley/status/136336985...      4
# ...                                                   ...
# https://twitter.com/Pays2Listen/status/13633177...      1
# https://twitter.com/PamelaBrownCNN/status/13636...      1
# https://twitter.com/PTSDGuts2/status/1363208879...      1
# https://twitter.com/POTUSJB4CTBT/status/1363308...      1
# https://twitter.com/amakaa_x/status/13642827375...      1
#
# [551 rows x 1 columns]

# %%
df["quote_url"] = df["quote_url"].astype(str)

# %%
df["quote_url"]
# Out:
# 0                                                     nan
# 1       https://twitter.com/Newsweek/status/1364580837...
# 2                                                     nan
# 3                                                     nan
# 4                                                     nan
#                               ...
# 9145                                                  nan
# 9146                                                  nan
# 9147                                                  nan
# 9148                                                  nan
# 9149                                                  nan
# Name: quote_url, Length: 9150, dtype: object

# %%
df["quote_url_new"] = df["quote_url"].apply(lambda x: "0" if x == "nan" or x=="0" else "1")

# %%
df[["quote_url_new","quote_url"]].head(200)
# Out:
#     quote_url_new                                          quote_url
# 0               0                                                nan
# 1               1  https://twitter.com/Newsweek/status/1364580837...
# 2               0                                                nan
# 3               0                                                nan
# 4               0                                                nan
# ..            ...                                                ...
# 195             0                                                nan
# 196             0                                                nan
# 197             0                                                nan
# 198             0                                                nan
# 199             0                                                nan
#
# [200 rows x 2 columns]

# %%
# Blank to be 0 or 1 otherwise

# %%
df["url"]
# Out:
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4       https://t.co/1TuMZ5O1eE
#                  ...
# 9145    https://t.co/iJrYlsmfrC
# 9146    https://t.co/77gfCAsKWb
# 9147                        NaN
# 9148    https://t.co/FtQpoISr3p
# 9149                        NaN
# Name: url, Length: 9150, dtype: object

# %%
df["url"] = df["url"].astype(str)

# %%
df["url"]
# Out:
# 0                           nan
# 1                           nan
# 2                           nan
# 3                           nan
# 4       https://t.co/1TuMZ5O1eE
#                  ...
# 9145    https://t.co/iJrYlsmfrC
# 9146    https://t.co/77gfCAsKWb
# 9147                        nan
# 9148    https://t.co/FtQpoISr3p
# 9149                        nan
# Name: url, Length: 9150, dtype: object

# %%
df.pivot_table(index="url",values="tweet",aggfunc="count").sort_values(by=["tweet"],ascending = False)
# Out:
#                          tweet
# url
# nan                       5808
# https://t.co/WCRfcb3mBb     26
# https://t.co/cXnat2KfIq     20
# https://t.co/ekaT92EzTE     12
# https://t.co/0F6431eC5t     11
# ...                        ...
# https://t.co/KOAcC3gD4j      1
# https://t.co/KRMj0oPO6r      1
# https://t.co/KSmDT4Xy2N      1
# https://t.co/KUWhiSorou      1
# https://t.co/TbHIvV1db0      1
#
# [2738 rows x 1 columns]

# %%
df["url_new"] = df["url"].apply(lambda x: "0" if x == "nan" else "1")

# %%
df[["url","url_new"]].head(200)
# Out:
#                          url url_new
# 0                        nan       0
# 1                        nan       0
# 2                        nan       0
# 3                        nan       0
# 4    https://t.co/1TuMZ5O1eE       1
# ..                       ...     ...
# 195                      nan       0
# 196                      nan       0
# 197                      nan       0
# 198                      nan       0
# 199                      nan       0
#
# [200 rows x 2 columns]

# %%
df["urls"] = df["urls_new"]
df["photos"] = df["photos_new"]
df["quote_url"] = df["quote_url_new"]
df["url"] = df["url_new"]

# %%
df.drop(['urls_new',"url_new","photos_new","retweet","quote_url_new"], axis='columns', inplace=True)

# %%
df[["tweet","urls","photos","video","nlikes","nreplies","nretweets","quote_url","url"]]
# Out:
#                                                   tweet urls photos  video  \
# 0     No suicidal shit. But, why the fuck I can't fi...    0      0      0
# 1     I'm a veteran who was medically discharged for...    0      0      0
# 2                    For me, your love is suicidal ????    0      0      0
# 3     not suicidal or anything but i genuinely can't...    0      0      0
# 4     Depression really made niggas think been suici...    0      0      0
# ...                                                 ...  ...    ...    ...
# 9145  Years ago, in no small part as a response to m...    0      0      0
# 9146  It can't be helped... In order to stop you tha...    0      0      0
# 9147  Bruh no suicidal shit but I swear my funeral g...    0      0      0
# 9148  Suicide information for those who are struggli...    0      1      1
# 9149  @Usherwood saw a sad looking pineapple by the ...    0      0      0
#
#         nlikes  nreplies  nretweets quote_url url
# 0     0.000000  0.000000   0.000000         0   0
# 1     0.000055  0.000000   0.000000         1   0
# 2     0.000000  0.000000   0.000000         0   0
# 3     0.001501  0.014837   0.001903         0   0
# 4     0.000022  0.000000   0.000050         0   1
# ...        ...       ...        ...       ...  ..
# 9145  0.001490  0.001484   0.000250         0   1
# 9146  0.000000  0.000000   0.000000         0   1
# 9147  0.000011  0.000000   0.000000         0   0
# 9148  0.000629  0.001484   0.001752         0   1
# 9149  0.000000  0.001484   0.000000         0   0
#
# [9150 rows x 9 columns]

# %% [markdown]
# # PY section ends
